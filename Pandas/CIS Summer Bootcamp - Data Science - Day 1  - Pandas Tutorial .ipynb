# %% [markdown]
# # CIS Summer Bootcamp - Data Science - Day 1

# %% [markdown]
# ## Session Tittle : Pandas Library

# %% [markdown]
# Python Pandas is defined as an open-source library that provides high-performance data manipulation in Python. This tutorial is designed for both beginners and professionals.

# %% [markdown]
# Pandas is defined as an open-source library that provides high-performance data manipulation in Python. The name of Pandas is derived from the word Panel Data, which means an Econometrics from Multidimensional data. It is used for data analysis in Python and developed by Wes McKinney in 2008.
#
# Data analysis requires lots of processing, such as restructuring, cleaning or merging, etc. There are different tools are available for fast data processing, such as Numpy, Scipy, Cython, and Panda. But we prefer Pandas because working with Pandas is fast, simple and more expressive than other tools.

# %% [markdown]
# ##  Series
# It is defined as a one-dimensional array that is capable of storing various data types. The row labels of series are called the index. We can easily convert the list, tuple, and dictionary into series using "series' method. A Series cannot contain multiple columns.

# %% [markdown]
# ![47ea98575c9f70b9055ef92f52c42bd1-2-800x214.png](attachment:47ea98575c9f70b9055ef92f52c42bd1-2-800x214.png)

# %% [markdown]
# ##  DataFrame
# It is a widely used data structure of pandas and works with a two-dimensional array with labeled axes (rows and columns). DataFrame is defined as a standard way to store data and has two different indexes, i.e., row index and column index.

# %% [markdown]
# ![series-and-dataframe.width-1200.png](attachment:series-and-dataframe.width-1200.png)

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Read Data

# %%
data = pd.read_csv("hr_data.csv")
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
excel_Data = pd.read_excel("Data_Set_Case_Study_Homework.xlsx")
excel_Data.head()
# Out:
#                                            Unit 1           Unnamed: 1  \
# 0    Employee census file as of December 31, 2016                  NaN
# 1                                             NaN                  NaN
# 2                                     Employee ID  Data Effective Date
# 3                                           A0001  2016-12-31 00:00:00
# 4                                           A0002  2016-12-31 00:00:00
#
#            Unnamed: 2                              Unnamed: 3  \
# 0                 NaN                                     NaN
# 1                 NaN                                     NaN
# 2  Employee\nStatus\n  Career Level \n(1=lowest, 6=highest)\n
# 3              Active                                       1
# 4              Active                                       1
#
#             Unnamed: 4             Unnamed: 5        Unnamed: 6  \
# 0                  NaN                    NaN               NaN
# ...

# %%
json_Data = pd.read_json("data.js")
json_Data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# ## Viewing data

# %%
# Pandas head() method is used to return top n (5 by default) rows of a data frame or series.
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %% [markdown]
# ![pandas-dataframe.png](attachment:pandas-dataframe.png)

# %%
# Pandas tail() method is used to return last n (5 by default) rows of a data frame or series.
data.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales salary
# 14994                      0  support    low
# 14995                      0  support    low
# 14996                      0  support    low
# ...

# %%
# Pandas sample() method is used to return random n (1 by default) rows of a data frame or series.
data.sample()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 8783                0.66             0.93               4
#
#       average_montly_hours  time_spend_company  Work_accident  left  \
# 8783                   248                   3              0     0
#
#       promotion_last_5years       sales salary
# 8783                      0  management   high

# %% [markdown]
# ## Pandas Dataframe.info() method

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Pandas Dataframe.shape

# %%
data.shape
# Out:
# (14999, 10)

# %% [markdown]
# ## Pandas Dataframe.uniqe

# %%
dataframe.sales.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-5680e29cea44> in <module>
# ----> 1 dataframe.sales.unique()
#
# NameError: name 'dataframe' is not defined

# %%
dataframe.sales.nunique()

# %%
dataframe.sales.value_counts()

# %% [markdown]
# ## Pandas Dataframe.describe() method

# %%
# Pandas describe() is used to view some basic statistical details like percentile, mean, std etc. 
data.describe()

# %%
data.sales.describe()

# %% [markdown]
# ## Select multiple columns

# %%
data_with_one_col = data["salary"]
data_with_one_col.head()

# %%
data_with_one_col.shape

# %%
new_Data = data[["salary" , "sales"]]

# %%
new_Data

# %%
new_Data.head()

# %%
new_Data.shape

# %%
new_Data.info()

# %% [markdown]
# ## pandas select method

# %%
data.select_dtypes(include= "number")

# %%
numerical_Data = data.select_dtypes(include= "number")
numerical_Data

# %%
data.select_dtypes(include= "object")

# %%
object_data = data.select_dtypes(include= "object")
object_data

# %% [markdown]
# ## Pandas corr function

# %%
dataframe.corr()

# %% [markdown]
# ## Drop and delete column

# %%
#In Order to delete a column in Pandas DataFrame, we can use the drop() method.
new_Data.head()

# %%
# dropping salary column 
new_Data.drop("salary" , inplace=True , axis = 1 )

# %%
new_Data.head(30)

# %%
new_Data = new_Data.drop(28)

# %%
new_Data.head(30)

# %% [markdown]
# ## Drop rows in DataFrame by conditions

# %%
dataframe = data.copy()

# %%
dataframe.shape

# %%
dataframe.head()

# %%
dataframe[dataframe['satisfaction_level'] > 0.50]

# %%
dataframe[(dataframe['satisfaction_level'] > 0.50) & (dataframe["last_evaluation"] > 0.50) ]

# %%
sample_data = dataframe[(dataframe['satisfaction_level'] > 0.50) & (dataframe["last_evaluation"] > 0.50) & (data['salary'] == "medium")]

# %%
sample_data_2 = dataframe[(dataframe['satisfaction_level'] < 0.50) & (dataframe["last_evaluation"] < 0.50) ].index

# %%
sample_data_2

# %%
dataframe.drop(sample_data_2 , inplace= True)

# %%
dataframe

# %%
dataframe.shape

# %% [markdown]
# ## Pandas DataFrame.loc[]

# %%
# Pandas provide a unique method to retrieve rows from a Data frame. 
# DataFrame.loc[] method is a method that takes only index labels
# and returns row or dataframe if the index label exists in the caller data frame.

# %%
dataframe_2 = dataframe.copy()

# %%
dataframe_2.head()

# %%
dataframe_2.set_index("salary" , inplace=True )

# %%
dataframe_2.sample(3)

# %%
# retrieving row by loc method 
data_loc_low = dataframe_2.loc['low']
data_loc_low

# %%
# retrieving row by loc method 
data_loc_high = dataframe_2.loc['high']
data_loc_high

# %%
# retrieving row by loc method 
data_loc_medium = dataframe_2.loc['medium']
data_loc_medium

# %% [markdown]
# ## Pandas DataFrame.iloc[]

# %%
# Dataframe.iloc[] method is used when the index label of a data frame
# is something other than numeric series of 0, 1, 2, 3….n or 
# in case the user doesn’t know the index label.

# %%
dataframe.head()

# %%
iloc_data = dataframe.iloc[0:20]
iloc_data

# %% [markdown]
# ## pandas-groupby

# %%
dataframe.sample()

# %%
dataframe_groupby =dataframe.groupby("time_spend_company").mean()
dataframe_groupby

# %%
dataframe_groupby =dataframe.groupby("time_spend_company").max()
dataframe_groupby

# %%
dataframe_groupby =dataframe.groupby("time_spend_company").min()
dataframe_groupby

# %%
dataframe_groupby =dataframe.groupby("time_spend_company").sum()
dataframe_groupby

# %% [markdown]
# ## Working with missing data

# %%
data.isnull()

# %%
data.isnull().sum()

# %%
data.isna().sum()

# %%
data.salary[0] = np.nan

# %%
data.isnull().sum()

# %%
##

# %% [markdown]
# ## Pandas append function

# %%
dataframe.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93498b4b2d50> in <module>
# ----> 1 dataframe.head()
#
# NameError: name 'dataframe' is not defined

# %%
part_data1 = dataframe.iloc[0:100]
part_data2 = dataframe.iloc[200:500]

# %%
part_data1

# %%
part_data2

# %%
two_data_parts = part_data2.append(part_data1)

# %%
two_data_parts

# %% [markdown]
# ## Pandas insert function

# %%
data.head()

# %%
data.insert(3 , column="inserted_column" , value="inserted !! ")

# %%
data

# %% [markdown]
# ## Pandas apply function

# %%
data.insert(1 , column="inserted_column_2" , value="one")

# %%
data

# %%
data.inserted_column_2=data.inserted_column_2.apply(lambda x : 1 if x == "one" else 0 )

# %%
data.inserted_column

# %%
data.inserted_column = data.inserted_column.replace("inserted !! " , 1 )

# %%
data.head()

# %%
data.inserted_column.dtype

# %%
data.dtypes

# %% [markdown]
# ## Pandas duplicated function

# %% [markdown]
# ![pandas-drop-duplicate-rows.png](attachment:pandas-drop-duplicate-rows.png)

# %%
dataframe.duplicated()

# %%
dataframe.drop_duplicates(inplace= True)

# %%
dataframe.shape
